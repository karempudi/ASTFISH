# %% [markdown]
# ### Fig 7 shows control experiments when you have single species and all the adapter and probes are pooled for the experiments
#
# ##### These figures are not generated by code.
#
# #### They are taken from the following experiments.
#
#
# - **EXP-22-BV6188** has E.coli and K.pneumoniae and their position numbers are **Pos60** and **Pos101** respectively
#
#
# - **EXP-22-BV6189** has E.faecalis and P.aureginosa and their position numbers are **Pos110** and **Pos58** respectively
#
#
#
# - **EXP-22-BV6190** has P.mirabilis and A.baumannii and their position numbers are **Pos155** and **Pos102** respectively
#
# - **EXP-22-BV6191** has S.aureus and **Pos104** was used
